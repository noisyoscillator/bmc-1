# %% [markdown]
# # Abrir arquivo

# %%
import numpy as np

# %%
# load data file
time, disp, disp2, aacc = np.loadtxt('./../data/Pezzack.txt', skiprows=6, unpack=True)

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# aacc       ndarray    142: 142 elems, type `float64`, 1136 bytes
# disp       ndarray    142: 142 elems, type `float64`, 1136 bytes
# disp2      ndarray    142: 142 elems, type `float64`, 1136 bytes
# np         module     <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# time       ndarray    142: 142 elems, type `float64`, 1136 bytes

# %% [markdown]
# # Plotar dados

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.figure(figsize=(8, 4))
plt.plot(time, disp, label='disp')
plt.plot(time, disp2, label='disp2')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, axs = plt.subplots (nrows=1, ncols=2, sharex=True, figsize=(8, 4), squeeze=True)
axs[0].plot(time, disp, label='disp')
axs[1].plot(time, aacc, label='aacc')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
dt = np.mean(np.diff(time))

v = np.diff(disp)/dt

a = np.diff(v)/dt

time = time[:-2]
disp = disp[:-2]
v    =    v[:-1]
aacc = aacc[:-2]

# %%
fig, axs = plt.subplots (nrows=1, ncols=2, sharex=True, figsize=(8, 4), squeeze=True)
axs[0].plot(time, disp, label='disp')
axs[0].legend()
axs[1].plot(time, aacc, label='aacc')
axs[1].plot(time, a, label='a')
axs[1].legend()
plt.show()
# Out:
# <img src="data:image/png;base64,...">
